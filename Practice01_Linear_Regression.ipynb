# %% [markdown]
# # 선형 회귀 학습 실습
#
# 이 노트북에서는 선형 회귀의 최소제곱법과 경사하강법을 단계별로 실습합니다.
#
# ## 사용할 수식
#
# **모델:**
# - 개별 샘플: $\hat{y}_n = w_0 + w_1 x_n = \mathbf{x}_n \mathbf{w}$
# - 매트릭스: $\hat{\mathbf{y}} = \mathbf{Xw}$
#
# **잔차 (residual):**
# - 개별: $E_n = y_n - \hat{y}_n$
# - 매트릭스: $\mathbf{E} = \mathbf{y} - \hat{\mathbf{y}}$
#
# **손실 함수 (MSE):**
# - 개별 샘플: $\ell^{(n)} = (y_n - \hat{y}_n)^2 = E_n^2$
# - 배치: $J = \sum_{n=1}^{N} \ell^{(n)} = \|\mathbf{E}\|_2^2 = \|\mathbf{y} - \hat{\mathbf{y}}\|_2^2$
#
# **기울기 (explicit negative form):**
# - 개별 샘플 기여: $\dfrac{\partial \ell^{(n)}}{\partial \mathbf{w}} = -(y_n - \hat{y}_n)\,\mathbf{x}_n^T = -E_n\,\mathbf{x}_n^T$ &nbsp; (shape: $(d+1) \times 1$)
# - 매트릭스: $\partial J / \partial \mathbf{w} = \sum_n -E_n\,\mathbf{x}_n^T = -\mathbf{X}^T (\mathbf{y} - \hat{\mathbf{y}}) = -\mathbf{X}^T \mathbf{E}$
#
# > $J = \|\mathbf{E}\|_2^2$ 를 그대로 미분하면 상수 2가 붙지만, 이 2는 학습률 $\rho$ 에 흡수시켜 생략한다.
# > (2를 붙이든 안 붙이든 $\rho$ 가 두 배 차이일 뿐 수렴 결과는 같다.)
#
# **가중치 갱신:**
#
# $$\mathbf{w} \leftarrow \mathbf{w} - \rho\, \partial J / \partial \mathbf{w} = \mathbf{w} + \rho\, \mathbf{X}^T \mathbf{E}$$
#
# **행렬 정의:**
#
# $$\mathbf{x} = \begin{bmatrix} x_1 \\ x_2 \\ \vdots \\ x_N \end{bmatrix}, \quad \mathbf{y} = \begin{bmatrix} y_1 \\ y_2 \\ \vdots \\ y_N \end{bmatrix}, \quad \mathbf{X} = \begin{bmatrix} 1 & x_1 \\ 1 & x_2 \\ \vdots & \vdots \\ 1 & x_N \end{bmatrix}, \quad \mathbf{w} = \begin{bmatrix} w_0 \\ w_1 \end{bmatrix}$$
#
# ---
#
# | Least Square Method | Gradient Descent Method |
# |:---|:---|
# | $J(\mathbf{w}) = \|\mathbf{y} - \hat{\mathbf{y}}\|_2^2$ | $J(\mathbf{w}) = \|\mathbf{y} - \hat{\mathbf{y}}\|_2^2$ |
# | $\partial J / \partial \mathbf{w} = -\mathbf{X}^T \mathbf{E} = 0$ | $\partial J / \partial \mathbf{w} = -\mathbf{X}^T \mathbf{E}$ |
# | $\mathbf{w}^* = (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T\mathbf{y}$ | $\mathbf{w} \leftarrow \mathbf{w} + \rho\,\mathbf{X}^T \mathbf{E}$ |

# %% [markdown]
# ---
# ## Step 0: 라이브러리 임포트

# %%
import numpy as np
import matplotlib.pyplot as plt

# 그래프 설정
plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ---
# ## Step 1: 데이터 생성
#
# $$y = 0.1 + 0.3 \, x + \mathcal{N}(0,\, 0.1)$$
#
# 으로부터 $N = 100$개 샘플을 생성합니다.

# %%
# 참값 (ground truth)
N  = 100       # 샘플 수
w0 = 0.1       # 절편
w1 = 0.3       # 기울기

# 데이터 생성
x = np.random.normal(0.0, 1, N).reshape(-1, 1)
y = w0 + w1 * x
y = y + np.random.normal(0.0, 0.1, N).reshape(-1, 1)

print(f"x shape: {x.shape}")
print(f"y shape: {y.shape}")
print(f"참값: w₀ = {w0}, w₁ = {w1}")

# 데이터 시각화
plt.figure()
plt.scatter(x, y, c='r', s=30, alpha=0.7, edgecolors='white', linewidths=0.5)
plt.xlabel('x', fontsize=13)
plt.ylabel('y', fontsize=13)
plt.title('Generated Data: $y = 0.1 + 0.3x + \\epsilon$', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# x shape: (100, 1)
# y shape: (100, 1)
# 참값: w₀ = 0.1, w₁ = 0.3

# %% [markdown]
# ---
# ## Step 2: 정규방정식으로 풀기 (Least Square Method)
#
# Augmented 행렬 $\mathbf{X}$를 구성하고, 정규방정식을 적용합니다.
#
# $$\mathbf{X} = \begin{bmatrix} 1 & x_1 \\ 1 & x_2 \\ \vdots & \vdots \\ 1 & x_N \end{bmatrix}, \qquad \mathbf{w}^* = (\mathbf{X}^T \mathbf{X})^{-1} \mathbf{X}^T \mathbf{y}$$

# %%
# Augmented 행렬 X 구성: [1, x]
X = np.hstack([x**0, x])

# 정규방정식: w* = (XᵀX)⁻¹ Xᵀy
# 여기서 np.linalg.inv()는 역행렬을 구하는 함수. 
# 그냥 (XᵀX)⁻¹로 쓸 수는 없음.
w_ls = np.linalg.inv(X.T @ X) @ X.T @ y

# y_hat (예측값)
y_hat = X @ w_ls

print(f"X shape: {X.shape}")
print(f"\n정규방정식 결과:")
print("=" * 40)
print(f"  w₀ (절편)  = {w_ls[0, 0]:.6f}  (참값: {w0})")
print(f"  w₁ (기울기) = {w_ls[1, 0]:.6f}  (참값: {w1})")
print("=" * 40)
# Out:
# X shape: (100, 2)
#
# 정규방정식 결과:
# ========================================
#   w₀ (절편)  = 0.102635  (참값: 0.1)
#   w₁ (기울기) = 0.299619  (참값: 0.3)
# ========================================

# %%
# 결과 시각화
plt.figure()
plt.scatter(x, y, c='r', s=30, alpha=0.7, edgecolors='white', linewidths=0.5, label='data')
plt.plot(x, y_hat, 'b-', linewidth=2.5,
         label=f'LS: $y = {w_ls[0,0]:.3f} + {w_ls[1,0]:.3f}x$')
plt.xlabel('x', fontsize=13)
plt.ylabel('y', fontsize=13)
plt.title('Least Square Solution: $\\mathbf{w}^* = (\\mathbf{X}^T\\mathbf{X})^{-1}\\mathbf{X}^T \\mathbf{y}$',
          fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 3: 경사하강법으로 풀기 (Gradient Descent Method)
#
# **손실 함수:**
# - 개별 샘플: $\ell^{(n)} = (y_n - \hat{y}_n)^2 = E_n^2$
# - 배치: $J = \sum_{n=1}^{N} \ell^{(n)} = \|\mathbf{E}\|_2^2$
#
# **기울기 (explicit negative form):**
# - 개별 샘플 기여: $\dfrac{\partial \ell^{(n)}}{\partial \mathbf{w}} = -E_n\,\mathbf{x}_n^T$ &nbsp; (shape: $(d+1) \times 1$)
# - 매트릭스: $\partial J / \partial \mathbf{w} = -\mathbf{X}^T \mathbf{E}$
#
# **가중치 갱신:**
#
# $$\mathbf{w} \leftarrow \mathbf{w} - \rho\, \partial J / \partial \mathbf{w} = \mathbf{w} + \rho\, \mathbf{X}^T \mathbf{E}$$

# %%
# 초기 파라미터 (랜덤)
w = np.random.randn(2, 1)

# 하이퍼파라미터
rho = 0.00002        # step size
n_iter = 3000        # 반복 횟수
w_history = []

print(f"초기 w = ({w[0,0]:.4f}, {w[1,0]:.4f})")
print(f"step size ρ = {rho}")
print(f"반복 횟수 = {n_iter}")
print()

# 경사하강법 반복
for i in range(n_iter):
    y_hat = X @ w                         # ŷ = Xw
    E = y - y_hat                         # 잔차 E = y - ŷ
    dJ = -X.T @ E                         # ∂J/∂w = -Xᵀ E
    w  = w - rho * dJ                     # w ← w - ρ·∂J/∂w
    w_history.append(w[:, 0])

    if i % 500 == 0 or i == n_iter - 1:
        loss = float(np.sum(E**2))        # J = ‖y - ŷ‖²
        print(f"iter={i:5d}  w₀={w[0,0]:+.6f}  w₁={w[1,0]:+.6f}  J={loss:.6f}")

# y_hat (예측값)
y_hat = X @ w

print()
print("최종 결과:")
print("=" * 40)
print(f"  w₀ = {w[0,0]:.6f}  (참값: {w0})")
print(f"  w₁ = {w[1,0]:.6f}  (참값: {w1})")
print("=" * 40)
# Out:
# 초기 w = (0.2275, 0.2996)
# step size ρ = 2e-05
# 반복 횟수 = 3000
#
# iter=    0  w₀=+0.227269  w₁=+0.299583  J=2.557903
# iter=  500  w₀=+0.148582  w₁=+0.296008  J=1.209003
# iter= 1000  w₀=+0.119678  w₁=+0.296969  J=1.027508
# iter= 1500  w₀=+0.108994  w₁=+0.298156  J=1.002482
# iter= 2000  w₀=+0.105022  w₁=+0.298899  J=0.998950
# iter= 2500  w₀=+0.103536  w₁=+0.299286  J=0.998441
# iter= 2999  w₀=+0.102978  w₁=+0.299470  J=0.998366
#
# 최종 결과:
# ========================================
#   w₀ = 0.102978  (참값: 0.1)
#   w₁ = 0.299470  (참값: 0.3)
# ========================================

# %%
# 회귀 직선 시각화
plt.figure()
plt.scatter(x, y, c='r', s=30, alpha=0.7, edgecolors='white', linewidths=0.5, label='data')
plt.plot(x, y_hat, 'b-', linewidth=2.5,
         label=f'GD: $y = {float(w[0,0]):.3f} + {float(w[1,0]):.3f}x$')
plt.xlabel('x', fontsize=13)
plt.ylabel('y', fontsize=13)
plt.title('Gradient Descent: $\\mathbf{w} \\leftarrow \\mathbf{w} - \\rho \\, \\partial J / \\partial \\mathbf{w}$',
          fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# w convergence
w_history = np.array(w_history)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# w₀ convergence
axes[0].plot(np.arange(n_iter), np.ones(n_iter) * w0,
             'r', linewidth=2, linestyle='--', label=f'true = {w0}')
axes[0].plot(w_history[:, 0], 'b', linewidth=1.5, label='$w_0$ (GD)')
axes[0].set_xlabel('Iteration', fontsize=12)
axes[0].set_ylabel('$w_0$', fontsize=13)
axes[0].set_title('$w_0$ Convergence', fontsize=13, fontweight='bold')
axes[0].legend(fontsize=10)
axes[0].grid(True, alpha=0.3)

# w₁ convergence
axes[1].plot(np.arange(n_iter), np.ones(n_iter) * w1,
             'r', linewidth=2, linestyle='--', label=f'true = {w1}')
axes[1].plot(w_history[:, 1], 'b', linewidth=1.5, label='$w_1$ (GD)')
axes[1].set_xlabel('Iteration', fontsize=12)
axes[1].set_ylabel('$w_1$', fontsize=13)
axes[1].set_title('$w_1$ Convergence', fontsize=13, fontweight='bold')
axes[1].legend(fontsize=10)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 전체 과정 요약
#
# | 단계 | 수식 | 설명 |
# |:---|:---|:---|
# | 데이터 | $y = 0.1 + 0.3x + \epsilon$ | $N=100$, $\epsilon \sim \mathcal{N}(0, 0.1)$ |
# | Augmented 행렬 | $\mathbf{X} = [\mathbf{1},\, \mathbf{x}]$ | shape: $(N, 2)$ |
# | 예측 | $\hat{\mathbf{y}} = \mathbf{Xw}$ | |
# | 잔차 | $\mathbf{E} = \mathbf{y} - \hat{\mathbf{y}}$ | target − pred |
# | 손실 | $J = \|\mathbf{E}\|^2 = \|\mathbf{y} - \hat{\mathbf{y}}\|^2$ | MSE |
# | 기울기 | $\partial J / \partial \mathbf{w} = -\mathbf{X}^T \mathbf{E}$ | explicit negative |
# | Least Square | $\mathbf{w}^* = (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T\mathbf{y}$ | 해석적 해 (closed-form) |
# | Gradient Descent | $\mathbf{w} \leftarrow \mathbf{w} + \rho\,\mathbf{X}^T \mathbf{E}$ | 반복적 최적화 |

# %% [markdown]
# ---
# ## 연습 문제
#
# 아래 셀에서 step size(`rho`)나 반복 횟수(`n_iter`)를 변경해보고, 수렴 과정이 어떻게 달라지는지 확인해보세요.
#
# 1. `rho = 0.0001`로 키우면 어떻게 되나요?
# 2. `n_iter = 100`으로 줄이면 수렴하나요?
# 3. 참값을 `w0 = 2.0`, `w1 = -0.5`로 바꾸고 처음부터 다시 해보세요.

# %%
# 여기에 코드를 작성하세요
